# %%
#int type
a = 5

#float type
b = 4.4

#string type
c = '100'

#boolean 
d = False

#variable reassignment
e = 10
e = 'huje ez a piton'

print(a,b,c,d,e,sep=', ')
print(type(d))

#
print(f'{a} < {b} is false or true? {a<b}')
f = a / b
print(f'What is the result of {a} / {b}? {f}')
print(type(f)) #python converses the types without your premission(crazy python!!!)

#converting variables
print(type(int(c)))

#asking for data
name = input('Your name: ')
print(name)

# %%
#Assignments
#Task 1-------------------
print('Task 1-------------------')
a1 = 1
b1 = 1
print(f'The sum: {a1+b1}, the difference: {a1-b1}, the product: {a1*b1}, the quotient: {a1/b1}')
print(f'The remainder of the division: {a1%b1}')
print(a1+1,b1-1)
print()
#Task 2-------------------
print('Task 2-------------------')
xmultiplayer = float(input('How many x-s do you want to be in this equation?'))
value = float(input('What should it be equal to?'))
print(f'{xmultiplayer}*x = {value}')
print(f'x equals to {value/xmultiplayer}')
print()
#Task 3-------------------
print('Task 3-------------------')
height = float(input('Please enter me the height of the cuboid: '))
width = float(input('Please enter me the widht of the cuboid: '))
depth = float(input('Please enter me the depth of the cuboid: '))
print(f'The surface of the cuboid is {2 * height * width+2*width*depth+2*depth*height}, the volume of the cuboid is {height * width * depth}')
print()
#Task 4-------------------
print('Task 4-------------------')
net = float(input('The given net price: '))
tax = float(input('The given tax rate(how many %): '))
print(f'The gross price of the notebook is {net*(1+tax/100)}')
print()
#Task 5-------------------
print('Task 5-------------------')
s1 = int(input('Final grade from subject 1: '))
s2 = int(input('Final grade from subject 2:'))
s3 = int(input('Final grade from subject 3:'))
s4 = int(input('Final grade from subject 4:'))
s5 = int(input('Final grade from subject 5:'))
print(f'The average of the final grades is: {(s1+s2+s3+s4+s5)/5}')
print()
#Task 6-------------------
print('Task 6-------------------')
amount = float(input('The amount we put in the bank: '))
interest = float(input('The interest rate(in %): '))
print(f'The final amount is {amount*(1+interest/100)*(1+interest/100)*(1+interest/100)*(1+interest/100)*(1+interest/100)}')
# Out:
# Task 1-------------------
# The sum: 2, the difference: 0, the product: 1, the quotient: 1.0
# The remainder of the division: 0
# 2 0
#
# Task 2-------------------
# How many x-s do you want to be in this equation?5
# What should it be equal to?5
# 5.0*x = 5.0
# x equals to 1.0
#
# Task 3-------------------
# Please enter me the height of the cuboid: 5
# Please enter me the widht of the cuboid: 5
# Please enter me the depth of the cuboid: 5
# The surface of the cuboid is 150.0, the volume of the cuboid is 125.0
#
# Task 4-------------------
# The given net price: 5
# The given tax rate(how many %): 5
# The gross price of the notebook is 5.25
#
# Task 5-------------------
# Final grade from subject 1: 5
# Final grade from subject 2:5
# Final grade from subject 3:5
# Final grade from subject 4:5
# Final grade from subject 5:5
# The average of the final grades is: 5.0
#
# Task 6-------------------
# The amount we put in the bank: 1000
# The interest rate(in %): 12
# ...
